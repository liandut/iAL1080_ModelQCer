# %% [markdown]
# # Validate and import manual decisions
#
# **Inputs:** review/HUMAN_REVIEW_PACKAGE.tsv
#
# **Outputs:** review/decisions/APPROVED_DECISIONS.tsv; REJECTED_DECISIONS.tsv; DEFERRED_DECISIONS.tsv; DECISION_VALIDATION_REPORT.md
#
# This notebook orchestrates existing functions and does not infer unresolved biology.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.config import load_context
ctx = load_context(ROOT)

# %%
from src.manual_review import import_decisions
result = import_decisions(ctx)
print(result)
