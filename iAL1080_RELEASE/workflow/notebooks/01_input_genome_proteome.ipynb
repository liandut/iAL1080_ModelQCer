# %% [markdown]
# # Genome/proteome input registration
#
# **Inputs:** config/project.yaml; input/genome; input/proteome
#
# **Outputs:** evidence/input_manifest.tsv; evidence/genome_statistics.tsv; evidence/proteome_statistics.tsv
#
# This notebook orchestrates existing functions and does not infer unresolved biology.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.config import load_context
ctx = load_context(ROOT)

# %%
from src.identifiers import scan_inputs
result = scan_inputs(ctx)
display(result['manifest'])
