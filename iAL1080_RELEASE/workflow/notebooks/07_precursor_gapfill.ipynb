# %% [markdown]
# # Prepare precursor-directed weighted-gapfill candidates
#
# **Inputs:** candidate model; existing weighted-pFBA results
#
# **Outputs:** evidence/gapfill/*.tsv; review/candidates/GAPFILL_REVIEW.tsv; models/candidates/LC1_GAPFILL_CANDIDATE.xml
#
# This notebook orchestrates existing functions and does not infer unresolved biology.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.config import load_context
ctx = load_context(ROOT)

# %%
from src.gapfill import prepare_gapfill_candidates
result = prepare_gapfill_candidates(ctx)
print(result)
