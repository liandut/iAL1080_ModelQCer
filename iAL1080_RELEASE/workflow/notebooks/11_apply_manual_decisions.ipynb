# %% [markdown]
# # Atomically apply approved manual decisions
#
# **Inputs:** last candidate model; review/decisions/APPROVED_DECISIONS.tsv
#
# **Outputs:** models/reviewed/LC1_REVIEWED_MODEL.xml; review/decisions/DECISION_APPLICATION_LOG.tsv
#
# This notebook orchestrates existing functions and does not infer unresolved biology.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.config import load_context
ctx = load_context(ROOT)

# %%
from src.decision_apply import apply_approved_decisions
result = apply_approved_decisions(ctx)
print(result)
