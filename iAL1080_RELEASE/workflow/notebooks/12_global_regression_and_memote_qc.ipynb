# %% [markdown]
# # Global regression and MEMOTE gate
#
# **Inputs:** models/reviewed/LC1_REVIEWED_MODEL.xml; config/media.yaml
#
# **Outputs:** qc/regression; qc/memote; qc/mass_charge; qc/blocked; qc/energy
#
# This notebook orchestrates existing functions and does not infer unresolved biology.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.config import load_context
ctx = load_context(ROOT)

# %%
from src.regression import run_regression
result = run_regression(ctx)
print(result)
