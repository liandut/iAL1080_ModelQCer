# %% [markdown]
# # Phenotype and essentiality validation
#
# **Inputs:** reviewed model; existing final phenotype assets
#
# **Outputs:** validation/carbon_sources/CARBON_PHENOTYPE_RESULTS.tsv; validation/essentiality/ESSENTIAL_GENES.tsv
#
# This notebook orchestrates existing functions and does not infer unresolved biology.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.config import load_context
ctx = load_context(ROOT)

# %%
from src.phenotype import prepare_phenotype_results
result = prepare_phenotype_results(ctx)
print(result)
